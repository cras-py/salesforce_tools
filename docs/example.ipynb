# %% [markdown]
# # Example usage
#
# To use `salesforce_tools` in a project:

# %%
import salesforce_tools
from salesforce_tools.salesforce_tools import SalesforceTools
import os

print(salesforce_tools.__version__)
# Out:
# 0.1.0

# %%
# Authenticate with your credentials here
user = 'crastello.py@gmail.com'
pw = os.environ.get('SFDC_PASS')
token = os.environ.get('SFDC_TOKEN')

sf = SalesforceTools(username=user,password=pw,security_token=token)

# %%
### Run a SOQL Query and return result as a df

soql = '''SELECT Id, Name, CloseDate, CreatedDate FROM Opportunity LIMIT 5'''

opps = sf.sf_api_query(soql=soql, dateList=['CloseDate','CreatedDate'],tz='America/Chicago')

# %%
sf.query_opportunities(dateList=['CreatedDate','CloseDate'],tz='America/Ney York')
# Out:
#                      Id                           Name            StageName  \
# 0    006a50000004MBeAAM        Opportunity for Conner5        Qualification
# 1    006a50000004MBfAAM    Opportunity for Chandler133  Perception Analysis
# 2    006a50000004MBjAAM     Opportunity for McDonald13          Closed Lost
# 3    006a50000004MBkAAM    Opportunity for Jefferson17           Closed Won
# 4    006a50000004MBlAAM  Opportunity for McLaughlin130   Negotiation/Review
# ..                  ...                            ...                  ...
# 701  006a50000004N1iAAE   Opportunity for Chandler1816  Perception Analysis
# 702  006a50000004N1jAAE        Opportunity for Fox1817           Closed Won
# 703  006a50000004N1kAAE      Opportunity for Hicks1818          Closed Lost
# 704  006a50000004N1lAAE       Opportunity for Moss1820  Perception Analysis
# 705  006a50000004N1mAAE      Opportunity for Miles1826          Closed Lost
#
#         Amount  CloseDate                   CreatedDate  IsWon  IsClosed  \
# 0      32400.0 2024-08-28  2024-02-10T08:26:48.000+0000  False     False
# 1     754640.0 2024-06-06  2024-02-10T08:26:48.000+0000  False     False
# 2     240747.0 2024-01-10  2024-02-10T08:26:48.000+0000  False      True
# 3      21640.0 2023-09-19  2024-02-10T08:26:48.000+0000   True      True
# 4    1249000.0 2024-03-18  2024-02-10T08:26:48.000+0000  False     False
# ..         ...        ...                           ...    ...       ...
# 701   470865.0 2024-06-10  2024-02-10T08:26:48.000+0000  False     False
# 702   807800.0 2023-08-24  2024-02-10T08:26:48.000+0000   True      True
# 703  1417400.0 2023-11-05  2024-02-10T08:26:48.000+0000  False      True
# 704  1489210.0 2024-06-11  2024-02-10T08:26:48.000+0000  False     False
# 705  5335150.0 2023-10-04  2024-02-10T08:26:48.000+0000  False      True
#
#                 OwnerId                   Type  Probability  \
# 0    005a500000039fEAAQ      Existing Business         10.0
# 1    005a500000039fDAAQ           New Business         70.0
# 2    005a500000039fDAAQ  New Business / Add-on          0.0
# 3    005a500000039fJAAQ  New Business / Add-on        100.0
# 4    005a500000039f8AAA      Existing Business         90.0
# ..                  ...                    ...          ...
# 701  005a500000039fAAAQ           New Business         70.0
# 702  005a500000039f9AAA      Existing Business        100.0
# 703  005a500000039fLAAQ  New Business / Add-on          0.0
# 704  005a500000039f6AAA           New Business         70.0
# 705  005a500000039fAAAQ      Existing Business          0.0
#
#               AccountId
# 0    001a5000000RKZdAAO
# 1    001a5000000RKCqAAO
# 2    001a5000000RKYaAAO
# 3    001a5000000RKZ8AAO
# 4    001a5000000RJhTAAW
# ..                  ...
# 701  001a5000000RKYXAA4
# 702  001a5000000RKZhAAO
# 703  001a5000000RJgpAAG
# 704  001a5000000RKafAAG
# 705  001a5000000RJ3lAAG
#
# [706 rows x 12 columns]
